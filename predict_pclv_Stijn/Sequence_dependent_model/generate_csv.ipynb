# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import process_library as preprocess
import preprocessing
import sys
sys.path.append('../../code_general')
reload(preprocess)
reload(preprocessing)
# Out:
# <module 'preprocessing' from 'preprocessing.pyc'>

# %%
guideE = 'GACGCATAAAGATGAGACGC'
filenameE = 'WT_cleavage_rate_and_y0.txt'
PathE = '../../data_nucleaseq_Finkelsteinlab/targetE/'
dataE = pd.read_table(PathE+filenameE, usecols=['target', 'cleavage_rate', 'cleavage_rate_5th_pctl', 'cleavage_rate_95th_pctl'])
dataE.rename(columns={'target':'Sequence'}, inplace=True)
print 'Length data frame: ',len(dataE)
dataE.head()
# Out:
# Length data frame:  12322
#                         Sequence  cleavage_rate  cleavage_rate_5th_pctl  \
# 0    TTTAGAGCGTATTTCATGAGACGCTGG   2.657239e-06            6.222793e-24
# 1  TTTAGACTGCGATAAAGATGAGACGCTGG   2.767674e-22            1.326366e-25
# 2  TTTAGACGCATAAAGATGAGACGCCTTAA   1.199120e-06            1.717058e-27
# 3  TTTAGACGCATAAAGATGAGACGCTAGGA   5.308185e-05            4.825889e-05
# 4  TTTAGACGTCAGTAAAGATGAGACGCTGG   8.747661e-25            7.856313e-27
#
#    cleavage_rate_95th_pctl
# 0                 0.000004
# 1                 0.000005
# 2                 0.000002
# 3                 0.000069
# 4                 0.000001

# %%
Cas='Cas9'
on_targetE = 'TTTA' + guideE + 'TGG'
seq_colname = 'Sequence'
output_colnames = ['cleavage_rate', 'cleavage_rate_5th_pctl', 'cleavage_rate_95th_pctl']
Canonical_PAM = True
Mut_type = ['OT','r']
Mut_min = 0
Mut_max = 2
out_file_name = filenameE.split('.')[0]
out_path = '../../data_nucleaseq_Finkelsteinlab/'

reload(preprocess)
new_dataE = preprocess.process_Finkelstein_Library(dataE, on_targetE, seq_colname, output_colnames, Cas, 
                                                  Canonical_PAM, Mut_type, Mut_min, Mut_max,
                                                  out_file_name = out_file_name, out_path = out_path, nofilter = False,
                                                  save_data = False)
new_dataE['Target']=preprocess.separate_PAM(on_targetE)[1]
new_dataE.to_csv('../../data_nucleaseq_Finkelsteinlab/WT_cleavage_rate_and_y0_Canonical_OT-r_0-2_target.csv', index=False)
print 'Length data frame: ',len(new_dataE)
new_dataE.head()
# Out:
# Length data frame:  5857
#                 Sequence  cleavage_rate  cleavage_rate_5th_pctl  \
# 5   CGCAGAGTAGAAAAACGCAG       0.006562                0.005024
# 6   CGCGGAGTAGAAATACGTAG       0.000542                0.000439
# 7   CGCAGAGTAGAAATACGCAG       0.182457                0.111880
# 12  CGCAGAGTAGAAATACGCAG       0.168158                0.112466
# 13  CGCAGAGTAGAAATACGCAG       0.210355                0.158494
#
#     cleavage_rate_95th_pctl  On Target  PAM  Canonical  Length difference  \
# 5                  0.008606      False  TGG       True                  0
# 6                  0.000817      False  TGG       True                  0
# 7                  0.191265       True  TGG       True                  0
# 12                 0.186088       True  TGG       True                  1
# 13                 0.312250       True  TGG       True                  0
#
#                                             Alignment  \
# 5   CGCAGAGTAGAAATACGCAG\n|||||||||||||.||||||\nCG...
# 6   CGCAGAGTAGAAATACGCAG\n|||.|||||||||||||.||\nCG...
# 7   CGCAGAGTAGAAATACGCAG\n||||||||||||||||||||\nCG...
# 12  CGCAGAGTAGAAATACGCAG-\n|||||||||||||||||||| \n...
# 13  CGCAGAGTAGAAATACGCAG\n||||||||||||||||||||\nCG...
#
#                                       Alignment (All)   Mutation ID  \
# 5   CGCAGAGTAGAAATA-CGCAG\n||||||||||||| | |||||\n...        r:14:A
# 6   CGCAG-AGTAGAAATACGC-AG\n||| | ||||||||||||  ||...  r:4:G|r:18:T
# 7   CGCAGAGTAGAAATACGCAG\n||||||||||||||||||||\nCG...            OT
# 12  CGCAGAGTAGAAATACGCAG-\n|||||||||||||||||||| \n...            OT
# 13  CGCAGAGTAGAAATACGCAG\n||||||||||||||||||||\nCG...            OT
#
#    Mutation Type  Mutation Count Mutation Positions                Target
# 5              r             1.0                 14  CGCAGAGTAGAAATACGCAG
# 6              r             2.0               4|18  CGCAGAGTAGAAATACGCAG
# 7             OT             0.0                     CGCAGAGTAGAAATACGCAG
# 12            OT             0.0                     CGCAGAGTAGAAATACGCAG
# 13            OT             0.0                     CGCAGAGTAGAAATACGCAG

# %%
path = '../../data_ABA_Finkelsteinlab/champ-cas9-cas12a-data/'
file = 'TargetE-dCas9_AbsoluteABA_Canonical_OT-r_0-2.csv'

data_aba = pd.read_csv(path+file)
#data_aba = data_aba[data_aba['Mutation Count']==1.]
data_aba['Target']=preprocess.separate_PAM(on_targetE)[1]
data_aba['sequence'] = data_aba['sequence'].apply(lambda x: preprocess.separate_PAM(x)[1])
data_aba.head()
data_aba.to_csv(path + 'TargetE-dCas9_AbsoluteABA_Canonical_OT-r_0-2_target.csv', index=False)

# %%
guideD = 'GTGATAAGTGGAATGCCATG'
filenameD = 'WT_cleavage_rate_and_y0.txt'
PathD = '../../data_nucleaseq_Finkelsteinlab/targetD/'
dataD = pd.read_table(PathD+filenameD, usecols=['target', 'cleavage_rate', 'cleavage_rate_5th_pctl', 'cleavage_rate_95th_pctl'])
dataD.rename(columns={'target':'Sequence'}, inplace=True)
print 'Length data frame: ',len(dataD)
dataD.head()
# Out:
# Length data frame:  8629
#                         Sequence  cleavage_rate  cleavage_rate_5th_pctl  \
# 0    TTTAGTGATCAGTGGAATGTCATGTGG   3.252077e-04            2.290311e-04
# 1  TTGTAGTGATAAGTGGAATCGCCATGTGG   5.840645e-25            6.486547e-27
# 2    TTTAGTGATAAGTGGCATGCCGTGTGG   8.556538e-18            2.214419e-25
# 3  ACGAACGTGATAAGTGGAATGCCATGTGG   2.161781e-01            1.283388e-01
# 4    TTTATTGATAAGTGGAATGCCATCTGG   2.839218e-04            2.441840e-04
#
#    cleavage_rate_95th_pctl
# 0                 0.000355
# 1                 0.000004
# 2                 0.000002
# 3                 0.235743
# 4                 0.000420

# %%
Cas='Cas9'
on_targetD = 'TTTA' + guideD + 'TGG'
seq_colname = 'Sequence'
output_colnames = ['cleavage_rate', 'cleavage_rate_5th_pctl', 'cleavage_rate_95th_pctl']
Canonical_PAM = True
Mut_type = ['OT','r']
Mut_min = 1
Mut_max = 1
out_file_name = filenameE.split('.')[0]
out_path = '../../data_nucleaseq_Finkelsteinlab/'

reload(preprocess)
new_dataD = preprocess.process_Finkelstein_Library(dataD, on_targetD, seq_colname, output_colnames, Cas, 
                                                  Canonical_PAM, Mut_type, Mut_min, Mut_max,
                                                  out_file_name = out_file_name, out_path = out_path, nofilter = False,
                                                  save_data = False)
new_dataD['Target']=preprocess.separate_PAM(on_targetD)[1]
new_dataD.to_csv('../../data_nucleaseq_Finkelsteinlab/WT_cleavage_rate_and_y0_Canonical_OT-r_1-1_target.csv', index=False)
print 'Length data frame: ',len(new_dataD)
new_dataD.head()
# Out:
# Length data frame:  963
#                 Sequence  cleavage_rate  cleavage_rate_5th_pctl  \
# 13  GTATCGTAAGGTGAATAGTG       0.001177                0.001013
# 15  GTACCGTAAGCTGAATAGTG       0.007223                0.004656
# 17  GTACCGTAGGGTGAATAGTG       0.036737                0.011979
# 41  GTACCGTAAGGTGACTAGTG       0.012065                0.008187
# 61  GTACTGTAAGGTGAATAGTG       0.003778                0.003500
#
#     cleavage_rate_95th_pctl  On Target  PAM  Canonical  Length difference  \
# 13                 0.001658      False  TGG       True                  0
# 15                 0.007470      False  TGG       True                  0
# 17                 0.037327      False  TGG       True                  0
# 41                 0.013944      False  TGG       True                  0
# 61                 0.006821      False  TGG       True                  0
#
#                                             Alignment  \
# 13  GTACCGTAAGGTGAATAGTG\n|||.||||||||||||||||\nGT...
# 15  GTACCGTAAGGTGAATAGTG\n||||||||||.|||||||||\nGT...
# 17  GTACCGTAAGGTGAATAGTG\n||||||||.|||||||||||\nGT...
# 41  GTACCGTAAGGTGAATAGTG\n||||||||||||||.|||||\nGT...
# 61  GTACCGTAAGGTGAATAGTG\n||||.|||||||||||||||\nGT...
#
#                                       Alignment (All) Mutation ID  \
# 13  GTAC-CGTAAGGTGAATAGTG\n|||  ||||||||||||||||\n...       r:4:T
# 15  GTACCGTAAGG-TGAATAGTG\n||||||||| | |||||||||\n...      r:11:C
# 17  GTACCGTAAGG-TGAATAGTG\n||||||| ||| |||||||||\n...       r:9:G
# 41  GTACCGTAAGGTGAA-TAGTG\n||||||||||||| | |||||\n...      r:15:C
# 61  GTACC-GTAAGGTGAATAGTG\n||| | |||||||||||||||\n...       r:5:T
#
#    Mutation Type  Mutation Count Mutation Positions                Target
# 13             r             1.0                  4  GTACCGTAAGGTGAATAGTG
# 15             r             1.0                 11  GTACCGTAAGGTGAATAGTG
# 17             r             1.0                  9  GTACCGTAAGGTGAATAGTG
# 41             r             1.0                 15  GTACCGTAAGGTGAATAGTG
# 61             r             1.0                  5  GTACCGTAAGGTGAATAGTG
